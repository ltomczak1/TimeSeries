# %% [markdown]
# #1. Install and Import Dependencies

# %%
#Install Prophet
# !pip install neuralprophet

# %%
import pandas as pd
from neuralprophet import NeuralProphet
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# # 2. Read in and Process Data

# %%
path = '/content/drive/MyDrive/weatherAUS.csv'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#          Date Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 0  2008-12-01   Albury     13.4  ...     21.8         No            No
# 1  2008-12-02   Albury      7.4  ...     24.3         No            No
# 2  2008-12-03   Albury     12.9  ...     23.2         No            No
# 3  2008-12-04   Albury      9.2  ...     26.5         No            No
# 4  2008-12-05   Albury     17.5  ...     29.7         No            No
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#               Date Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 145455  2017-06-21    Uluru      2.8  ...     22.4         No            No
# 145456  2017-06-22    Uluru      3.6  ...     24.5         No            No
# 145457  2017-06-23    Uluru      5.4  ...     26.1         No            No
# 145458  2017-06-24    Uluru      7.8  ...     26.0         No            No
# 145459  2017-06-25    Uluru     14.9  ...     20.9         No           NaN
#
# [5 rows x 23 columns]

# %%
#Let's explore our features
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
#Let's see how many locations we have
df.Location.unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
#Let's explore our data types for the features
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
#Prophet requires the date as a datetime format
df['Date'] = pd.to_datetime(df['Date'])

#Confirm our date is datetime
df.dtypes
# Out:
# Date             datetime64[ns]
# Location                 object
# MinTemp                 float64
# MaxTemp                 float64
# Rainfall                float64
# Evaporation             float64
# Sunshine                float64
# WindGustDir              object
# WindGustSpeed           float64
# WindDir9am               object
# WindDir3pm               object
# WindSpeed9am            float64
# WindSpeed3pm            float64
# Humidity9am             float64
# Humidity3pm             float64
# Pressure9am             float64
# Pressure3pm             float64
# Cloud9am                float64
# Cloud3pm                float64
# Temp9am                 float64
# Temp3pm                 float64
# RainToday                object
# RainTomorrow             object
# dtype: object

# %%
#We'll filter out a chosen location - Melbourne
melb = df[df['Location'] == 'Melbourne']

#Confirm we are working with Melbourne
melb.head()
# Out:
#             Date   Location  MinTemp  ...  Temp3pm  RainToday  RainTomorrow
# 67200 2008-07-01  Melbourne      9.5  ...     14.6        Yes            No
# 67201 2008-07-02  Melbourne     11.0  ...     13.7         No           Yes
# 67202 2008-07-03  Melbourne      8.4  ...     13.9        Yes            No
# 67203 2008-07-04  Melbourne      9.1  ...     13.1         No            No
# 67204 2008-07-05  Melbourne      4.3  ...     14.6         No            No
#
# [5 rows x 23 columns]

# %%
#Confirm all datatypes are correct
melb.dtypes
# Out:
# Date             datetime64[ns]
# Location                 object
# MinTemp                 float64
# MaxTemp                 float64
# Rainfall                float64
# Evaporation             float64
# Sunshine                float64
# WindGustDir              object
# WindGustSpeed           float64
# WindDir9am               object
# WindDir3pm               object
# WindSpeed9am            float64
# WindSpeed3pm            float64
# Humidity9am             float64
# Humidity3pm             float64
# Pressure9am             float64
# Pressure3pm             float64
# Cloud9am                float64
# Cloud3pm                float64
# Temp9am                 float64
# Temp3pm                 float64
# RainToday                object
# RainTomorrow             object
# dtype: object

# %%
#Let's explore temperature visually
plt.plot(melb['Date'], melb['Temp3pm'])
plt.show()

# %%
#We are missing a chunk of data that cannot be reasonably imputed. Let's remove after 2015
#Extract the year into a new column
melb['Year'] = melb['Date'].apply(lambda x: x.year)
#Filter prior to end of 2015
melb = melb[melb['Year'] <= 2015]

#Confirm by visualizing
plt.plot(melb['Date'], melb['Temp3pm'])
plt.show()
# Out:
# <ipython-input-78-f4aeb30c07b7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melb['Year'] = melb['Date'].apply(lambda x: x.year)

# %%
#Select only dates and target
data = melb[['Date', 'Temp3pm']]
#Rename the columns
data.columns = ['ds', 'y']
#Drop remaining missing data
data.dropna(inplace = True)

data.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#               ds     y
# 67200 2008-07-01  14.6
# 67201 2008-07-02  13.7
# 67202 2008-07-03  13.9
# 67203 2008-07-04  13.1
# 67204 2008-07-05  14.6

# %% [markdown]
# # 3. Train Model

# %%
#Instantiate model
model = NeuralProphet()

#Fit model, daily frequency
model.fit(data, freq = 'D', epochs = 1000)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.694% of the data.
# INFO:NP.df_utils:Major frequency D corresponds to 99.694% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO:NP.df_utils:Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO:NP.config:Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO:NP.utils:Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO:NP.config:Auto-set batch_size to 32
# ...

# %% [markdown]
# # 4. Forecast and Evaluate

# %%
#Create future periods
future = model.make_future_dataframe(data, periods = 1200)
#Forecast
forecast = model.predict(future)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.694% of the data.
# INFO:NP.df_utils:Major frequency D corresponds to 99.694% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO:NP.df_utils:Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO:NP.df_utils:Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.917% of the data.
# INFO:NP.df_utils:Major frequency D corresponds to 99.917% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO:NP.df_utils:Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 99.917% of the data.
# INFO:NP.df_utils:Major frequency D corresponds to 99.917% of the data.
# ...

# %%
#View future periods
future
# Out:
#              ds     y
# 0    2015-01-06  None
# 1    2015-01-07  None
# 2    2015-01-08  None
# 3    2015-01-09  None
# 4    2015-01-10  None
# ...         ...   ...
# 1195 2018-04-15  None
# 1196 2018-04-16  None
# 1197 2018-04-17  None
# 1198 2018-04-18  None
# 1199 2018-04-19  None
#
# [1200 rows x 2 columns]

# %%
#View forecast values
forecast.head()
# Out:
#           ds     y      yhat1      trend  season_yearly  season_weekly
# 0 2015-01-06  None  25.879871  20.281096       5.308219       0.290557
# 1 2015-01-07  None  25.694248  20.281906       5.448238      -0.035898
# 2 2015-01-08  None  25.945602  20.282719       5.584281       0.078604
# 3 2015-01-09  None  26.035343  20.283531       5.715626       0.036187
# 4 2015-01-10  None  26.105671  20.284344       5.841588      -0.020261

# %%
forecast.tail()
# Out:
#              ds     y      yhat1      trend  season_yearly  season_weekly
# 1195 2018-04-15  None  21.777464  21.251194       0.545404      -0.019133
# 1196 2018-04-16  None  21.310308  21.252005       0.388359      -0.330055
# 1197 2018-04-17  None  21.777695  21.252815       0.234321       0.290557
# 1198 2018-04-18  None  21.301365  21.253628       0.083634      -0.035898
# 1199 2018-04-19  None  21.269646  21.254440      -0.063398       0.078604

# %%
#Visualize our forecast
plot1 = model.plot(forecast)
# Out:
# WARNING - (NP.plotting.log_warning_deprecation_plotly) - DeprecationWarning: default plotting_backend will be changed to plotly in a future version. Switch to plotly by calling `m.set_plotting_backend('plotly')`.
# WARNING:NP.plotting:DeprecationWarning: default plotting_backend will be changed to plotly in a future version. Switch to plotly by calling `m.set_plotting_backend('plotly')`.

# %%
#Visualize components
plot2 = model.plot_components(forecast)
# Out:
# WARNING - (NP.plotting.log_warning_deprecation_plotly) - DeprecationWarning: default plotting_backend will be changed to plotly in a future version. Switch to plotly by calling `m.set_plotting_backend('plotly')`.
# WARNING:NP.plotting:DeprecationWarning: default plotting_backend will be changed to plotly in a future version. Switch to plotly by calling `m.set_plotting_backend('plotly')`.

# %% [markdown]
# # Save Model

# %%
#Use pickle to save model (write binary)
with open('weather_forecast.pkkl', 'wb') as f:
  pickle.dump(model, f)

# %%
#Use pickle to load model (read binaery)
#with open('weather_forecast.pkkl', 'rb') as f:
  #model = pickle.load(f)
